# %%
from keras.datasets import mnist
import matplotlib.pyplot as plt
import numpy as np
(x_tr,y_tr),(x_t,y_t)=mnist.load_data()
for i in range(1,10):
  plt.subplot(330+i)
  plt.imshow(x_t[i],cmap='gray')
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step
# 11501568/11490434 [==============================] - 0s 0us/step

# %%
from keras.datasets import mnist
from sklearn import utils
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout,Conv2D,MaxPooling2D,Flatten
from tensorflow.keras.optimizers import RMSprop,Adam
import numpy as np
from keras.utils import np_utils
import pandas as pd
from keras.callbacks import EarlyStopping 
import matplotlib.pyplot as plt

# Load data
(x_train,y_train),(x_test,y_test)=mnist.load_data()

# Force to data type
x_train=x_train.astype('float32')
x_test=x_test.astype('float32')

x_train=x_train.reshape(60000,28,28,1)
x_test=x_test.reshape(10000,28,28,1)
# Divide in 255 to ensure value always between 0 and 1
x_train/=255
x_test/=255

# Convert labels to one hot-encoding
y_train=np_utils.to_categorical(y_train,10)
y_test=np_utils.to_categorical(y_test,10)


# Create model 
model = Sequential()
model.add(Conv2D(64,(3,3),activation='relu',input_shape=(28,28,1)))
model.add(MaxPooling2D(2,2))
model.add(Conv2D(64,(3,3),input_shape=(28,28),activation='relu'))
model.add(MaxPooling2D(2,2))
model.add(Flatten())
model.add(Dense(128,activation='relu'))
model.add(Dense(10, activation='softmax'))
model.summary()

# Compile
model.compile(optimizer='Adam', loss='categorical_crossentropy', metrics=['accuracy'])
# Training
history=model.fit(x_train,y_train,batch_size=128,epochs=500,verbose=1,validation_data=(x_test,y_test),callbacks=[EarlyStopping(monitor='val_loss',patience=20)])
# Plot
plt.plot(history.history['accuracy'])
plt.xlabel('epoch')
plt.legend(['accuracy'])
plt.show()

# Evaluate
score = model.evaluate(x_test, y_test, verbose=0)
print('Test error:',score[0])
print('Test accuracy: ',score[1])

# Predict
print(x_test.shape)
y_predict = model.predict(x_test[3].reshape(1,28,28,1))
print('Predicted value: ', np.argmax(y_predict))
print('Correct value: ',np.argmax(y_test[3]))
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 26, 26, 64)        640
#
#  max_pooling2d (MaxPooling2D  (None, 13, 13, 64)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 11, 11, 64)        36928
#
#  max_pooling2d_1 (MaxPooling  (None, 5, 5, 64)         0
#  2D)
#
#  flatten (Flatten)           (None, 1600)              0
#
#  dense (Dense)               (None, 128)               204928
#
#  dense_1 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 243,786
# Trainable params: 243,786
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/500
# 469/469 [==============================] - 16s 12ms/step - loss: 0.1936 - accuracy: 0.9428 - val_loss: 0.0501 - val_accuracy: 0.9833
# Epoch 2/500
# 469/469 [==============================] - 5s 11ms/step - loss: 0.0514 - accuracy: 0.9846 - val_loss: 0.0423 - val_accuracy: 0.9858
# Epoch 3/500
# 469/469 [==============================] - 6s 13ms/step - loss: 0.0349 - accuracy: 0.9891 - val_loss: 0.0272 - val_accuracy: 0.9911
# Epoch 4/500
# 469/469 [==============================] - 5s 11ms/step - loss: 0.0261 - accuracy: 0.9919 - val_loss: 0.0291 - val_accuracy: 0.9906
# Epoch 5/500
# 469/469 [==============================] - 5s 11ms/step - loss: 0.0197 - accuracy: 0.9937 - val_loss: 0.0279 - val_accuracy: 0.9919
# Epoch 6/500
# 469/469 [==============================] - 5s 11ms/step - loss: 0.0161 - accuracy: 0.9950 - val_loss: 0.0357 - val_accuracy: 0.9892
# Epoch 7/500
# 469/469 [==============================] - 5s 11ms/step - loss: 0.0134 - accuracy: 0.9954 - val_loss: 0.0323 - val_accuracy: 0.9906
# Epoch 8/500
# 469/469 [==============================] - 5s 11ms/step - loss: 0.0106 - accuracy: 0.9968 - val_loss: 0.0282 - val_accuracy: 0.9918
# Epoch 9/500
# 469/469 [==============================] - 5s 11ms/step - loss: 0.0083 - accuracy: 0.9973 - val_loss: 0.0365 - val_accuracy: 0.9907
# Epoch 10/500
# 469/469 [==============================] - 6s 12ms/step - loss: 0.0075 - accuracy: 0.9974 - val_loss: 0.0317 - val_accuracy: 0.9910
# Epoch 11/500
# 469/469 [==============================] - 5s 11ms/step - loss: 0.0069 - accuracy: 0.9976 - val_loss: 0.0298 - val_accuracy: 0.9916
# Epoch 12/500
# 469/469 [==============================] - 5s 11ms/step - loss: 0.0054 - accuracy: 0.9982 - val_loss: 0.0379 - val_accuracy: 0.9899
# Epoch 13/500
# 469/469 [==============================] - 5s 11ms/step - loss: 0.0053 - accuracy: 0.9982 - val_loss: 0.0341 - val_accuracy: 0.9914
# Epoch 14/500
# 469/469 [==============================] - 5s 11ms/step - loss: 0.0050 - accuracy: 0.9983 - val_loss: 0.0406 - val_accuracy: 0.9907
# Epoch 15/500
# 469/469 [==============================] - 6s 12ms/step - loss: 0.0049 - accuracy: 0.9982 - val_loss: 0.0493 - val_accuracy: 0.9897
# Epoch 16/500
# 469/469 [==============================] - 6s 12ms/step - loss: 0.0044 - accuracy: 0.9987 - val_loss: 0.0335 - val_accuracy: 0.9921
# Epoch 17/500
# 469/469 [==============================] - 6s 12ms/step - loss: 0.0021 - accuracy: 0.9994 - val_loss: 0.0353 - val_accuracy: 0.9926
# Epoch 18/500
# 469/469 [==============================] - 5s 11ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0448 - val_accuracy: 0.9909
# Epoch 19/500
# 469/469 [==============================] - 5s 11ms/step - loss: 0.0063 - accuracy: 0.9977 - val_loss: 0.0412 - val_accuracy: 0.9912
# Epoch 20/500
# 469/469 [==============================] - 5s 11ms/step - loss: 0.0035 - accuracy: 0.9988 - val_loss: 0.0365 - val_accuracy: 0.9920
# Epoch 21/500
# 469/469 [==============================] - 6s 12ms/step - loss: 0.0017 - accuracy: 0.9995 - val_loss: 0.0471 - val_accuracy: 0.9914
# Epoch 22/500
# 469/469 [==============================] - 6s 12ms/step - loss: 5.9917e-04 - accuracy: 0.9998 - val_loss: 0.0417 - val_accuracy: 0.9925
# Epoch 23/500
# 469/469 [==============================] - 6s 12ms/step - loss: 0.0020 - accuracy: 0.9995 - val_loss: 0.0734 - val_accuracy: 0.9878
# Test error: 0.073424331843853
# Test accuracy:  0.9878000020980835
# (10000, 28, 28, 1)
# Predicted value:  0
# Correct value:  0
